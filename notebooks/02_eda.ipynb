# %%
import pandas as pd

df = pd.read_csv("../data/diabetic_data_cleaned.csv")

print("Dataset loaded successfully!")
print("Shape:", df.shape)
# Out:
# C:\Users\rgukt\AppData\Local\Temp\ipykernel_5908\2794401719.py:3: DtypeWarning: Columns (0: payer_code) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/diabetic_data_cleaned.csv")
# Dataset loaded successfully!
# Shape: (101766, 50)

# %%
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)    NaN
# 1        149190     55629189        Caucasian  Female  [10-20)    NaN
# 2         64410     86047875  AfricanAmerican  Female  [20-30)    NaN
# 3        500364     82442376        Caucasian    Male  [30-40)    NaN
# 4         16680     42519267        Caucasian    Male  [40-50)    NaN
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
for i, column in enumerate(df.columns, start=1):
    print(i, "→", column)
# Out:
# 1 → encounter_id
# 2 → patient_nbr
# 3 → race
# 4 → gender
# 5 → age
# 6 → weight
# 7 → admission_type_id
# 8 → discharge_disposition_id
# 9 → admission_source_id
# 10 → time_in_hospital
# 11 → payer_code
# 12 → medical_specialty
# 13 → num_lab_procedures
# 14 → num_procedures
# 15 → num_medications
# 16 → number_outpatient
# 17 → number_emergency
# 18 → number_inpatient
# 19 → diag_1
# 20 → diag_2
# 21 → diag_3
# 22 → number_diagnoses
# 23 → max_glu_serum
# 24 → A1Cresult
# 25 → metformin
# 26 → repaglinide
# 27 → nateglinide
# 28 → chlorpropamide
# 29 → glimepiride
# 30 → acetohexamide
# 31 → glipizide
# 32 → glyburide
# 33 → tolbutamide
# 34 → pioglitazone
# 35 → rosiglitazone
# 36 → acarbose
# 37 → miglitol
# 38 → troglitazone
# 39 → tolazamide
# 40 → examide
# 41 → citoglipton
# 42 → insulin
# 43 → glyburide-metformin
# 44 → glipizide-metformin
# 45 → glimepiride-pioglitazone
# 46 → metformin-rosiglitazone
# 47 → metformin-pioglitazone
# 48 → change
# 49 → diabetesMed
# ...

# %%
df.describe()
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  1.017660e+05  1.017660e+05      101766.000000
# mean   1.652016e+08  5.433040e+07           2.024006
# std    1.026403e+08  3.869636e+07           1.445403
# min    1.252200e+04  1.350000e+02           1.000000
# 25%    8.496119e+07  2.341322e+07           1.000000
# 50%    1.523890e+08  4.550514e+07           1.000000
# 75%    2.302709e+08  8.754595e+07           3.000000
# max    4.438672e+08  1.895026e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# ...

# %%
print(df["readmitted"].value_counts())
# Out:
# readmitted
# NO     54864
# >30    35545
# <30    11357
# Name: count, dtype: int64

# %%
print(df["readmitted"].value_counts(normalize=True) * 100)
# Out:
# readmitted
# NO     53.911916
# >30    34.928169
# <30    11.159916
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt

df["readmitted"].value_counts().plot(kind="bar")

plt.title("Patient Readmission Distribution")
plt.xlabel("Readmission Status")
plt.ylabel("Number of Encounters")
plt.xticks(rotation=0)
plt.show()

# %%
age_counts = df["age"].value_counts().sort_index()

print(age_counts)
# Out:
# age
# [0-10)        161
# [10-20)       691
# [20-30)      1657
# [30-40)      3775
# [40-50)      9685
# [50-60)     17256
# [60-70)     22483
# [70-80)     26068
# [80-90)     17197
# [90-100)     2793
# Name: count, dtype: int64

# %%
age_counts.plot(kind="bar")

plt.title("Patient Distribution by Age Group")
plt.xlabel("Age Group")
plt.ylabel("Number of Patients")
plt.xticks(rotation=45)
plt.show()

# %%
gender_counts = df["gender"].value_counts()

print(gender_counts)
# Out:
# gender
# Female             54708
# Male               47055
# Unknown/Invalid        3
# Name: count, dtype: int64

# %%
df["readmitted_30"] = (df["readmitted"] == "<30").astype(int)

# %%
age_readmission = df.groupby("age")["readmitted_30"].mean() * 100
print(age_readmission)
# Out:
# age
# [0-10)       1.863354
# [10-20)      5.788712
# [20-30)     14.242607
# [30-40)     11.231788
# [40-50)     10.604027
# [50-60)      9.666203
# [60-70)     11.128408
# [70-80)     11.773055
# [80-90)     12.083503
# [90-100)    11.099177
# Name: readmitted_30, dtype: float64

# %%
age_readmission.plot(kind="bar")

plt.title("30-Day Readmission Rate by Age Group")
plt.xlabel("Age Group")
plt.ylabel("Readmission Rate (%)")
plt.xticks(rotation=45)
plt.show()

# %%
gender_readmission = df.groupby("gender")["readmitted_30"].mean() * 100

print(gender_readmission)
# Out:
# gender
# Female             11.245156
# Male               11.061524
# Unknown/Invalid     0.000000
# Name: readmitted_30, dtype: float64

# %%
gender_readmission.plot(kind="bar")

plt.title("30-Day Readmission Rate by Gender")
plt.xlabel("Gender")
plt.ylabel("Readmission Rate (%)")
plt.xticks(rotation=0)
plt.show()

# %%
stay_readmission = df.groupby("time_in_hospital")["readmitted_30"].mean() * 100

print(stay_readmission)
# Out:
# time_in_hospital
# 1      8.178491
# 2      9.939619
# 3     10.666817
# 4     11.806952
# 5     12.030905
# 6     12.587876
# 7     12.834955
# 8     14.233660
# 9     13.724184
# 10    14.346712
# 11    10.512129
# 12    13.328729
# 13    12.314050
# 14    12.955854
# Name: readmitted_30, dtype: float64

# %%
inpatient_readmission = df.groupby("number_inpatient")["readmitted_30"].mean() * 100

print(inpatient_readmission)
# Out:
# number_inpatient
# 0       8.437084
# 1      12.924543
# 2      17.433254
# 3      20.287306
# 4      23.612824
# 5      31.403941
# 6      34.583333
# 7      35.447761
# 8      44.370861
# 9      42.342342
# 10     42.622951
# 11     67.346939
# 12     50.000000
# 13     50.000000
# 14     40.000000
# 15    100.000000
# 16     33.333333
# 17    100.000000
# 18      0.000000
# 19     50.000000
# 21    100.000000
# Name: readmitted_30, dtype: float64

# %%
inpatient_readmission.plot(kind="line", marker="o")

plt.title("30-Day Readmission Rate vs Previous Inpatient Visits")
plt.xlabel("Number of Previous Inpatient Visits")
plt.ylabel("Readmission Rate (%)")
plt.grid()
plt.show()

# %%
emergency_readmission = df.groupby("number_emergency")["readmitted_30"].mean() * 100

print(emergency_readmission)
# Out:
# number_emergency
# 0      10.474315
# 1      14.354566
# 2      18.266405
# 3      20.275862
# 4      30.748663
# 5      24.479167
# 6      23.404255
# 7      26.027397
# 8      32.000000
# 9      36.363636
# 10     35.294118
# 11     21.739130
# 12     20.000000
# 13     33.333333
# 14      0.000000
# 15     33.333333
# 16     40.000000
# 18     20.000000
# 19     50.000000
# 20     50.000000
# 21     50.000000
# 22     50.000000
# 24      0.000000
# 25      0.000000
# 28    100.000000
# 29      0.000000
# 37      0.000000
# 42      0.000000
# 46      0.000000
# 54      0.000000
# 63      0.000000
# 64    100.000000
# 76      0.000000
# Name: readmitted_30, dtype: float64

# %%
print(df["number_emergency"].value_counts().sort_index())
# Out:
# number_emergency
# 0     90383
# 1      7677
# 2      2042
# 3       725
# 4       374
# 5       192
# 6        94
# 7        73
# 8        50
# 9        33
# 10       34
# 11       23
# 12       10
# 13       12
# 14        3
# 15        3
# 16        5
# 18        5
# 19        4
# 20        4
# 21        2
# 22        6
# 24        1
# 25        2
# 28        1
# 29        1
# 37        1
# 42        1
# 46        1
# 54        1
# 63        1
# 64        1
# 76        1
# Name: count, dtype: int64

# %%
medication_readmission = df.groupby("num_medications")["readmitted_30"].mean() * 100

print(medication_readmission)
# Out:
# num_medications
# 1       4.198473
# 2       8.297872
# 3       7.222222
# 4       8.045166
# 5       7.436787
#          ...
# 72    100.000000
# 74      0.000000
# 75      0.000000
# 79      0.000000
# 81    100.000000
# Name: readmitted_30, Length: 75, dtype: float64

# %%
print(df["num_medications"].value_counts().sort_index())
# Out:
# num_medications
# 1      262
# 2      470
# 3      900
# 4     1417
# 5     2017
#       ...
# 72       3
# 74       1
# 75       2
# 79       1
# 81       1
# Name: count, Length: 75, dtype: int64

# %%
medication_readmission.plot(kind="line", marker="o")

plt.title("30-Day Readmission Rate vs Number of Medications")
plt.xlabel("Number of Medications")
plt.ylabel("Readmission Rate (%)")
plt.grid()
plt.show()

# %%
diagnosis_readmission = df.groupby("number_diagnoses")["readmitted_30"].mean() * 100

print(diagnosis_readmission)
# Out:
# number_diagnoses
# 1      5.936073
# 2      6.060606
# 3      7.372134
# 4      8.253567
# 5      9.154744
# 6     10.412361
# 7     10.766862
# 8     11.812359
# 9     12.380240
# 10    17.647059
# 11    27.272727
# 12    11.111111
# 13    18.750000
# 14    14.285714
# 15    20.000000
# 16     8.888889
# Name: readmitted_30, dtype: float64

# %%
print(df["number_diagnoses"].value_counts().sort_index())
# Out:
# number_diagnoses
# 1       219
# 2      1023
# 3      2835
# 4      5537
# 5     11393
# 6     10161
# 7     10393
# 8     10616
# 9     49474
# 10       17
# 11       11
# 12        9
# 13       16
# 14        7
# 15       10
# 16       45
# Name: count, dtype: int64

# %%
diagnosis_readmission.plot(kind="line", marker="o")

plt.title("30-Day Readmission Rate vs Number of Diagnoses")
plt.xlabel("Number of Diagnoses")
plt.ylabel("Readmission Rate (%)")
plt.grid()
plt.show()

# %%
print(df["A1Cresult"].value_counts(dropna=False))
# Out:
# A1Cresult
# NaN     84748
# >8       8216
# Norm     4990
# >7       3812
# Name: count, dtype: int64

# %%
a1c_readmission = df.groupby("A1Cresult", dropna=False)["readmitted_30"].mean() * 100

print(a1c_readmission)
# Out:
# A1Cresult
# >7      10.047219
# >8       9.870983
# Norm     9.659319
# NaN     11.423278
# Name: readmitted_30, dtype: float64

# %%
a1c_readmission.plot(kind="bar")

plt.title("30-Day Readmission Rate by A1C Result")
plt.xlabel("A1C Result")
plt.ylabel("Readmission Rate (%)")
plt.xticks(rotation=0)
plt.show()

# %%
print(df["max_glu_serum"].value_counts(dropna=False))
# Out:
# max_glu_serum
# NaN     96420
# Norm     2597
# >200     1485
# >300     1264
# Name: count, dtype: int64

# %%
print(df["diabetesMed"].value_counts())
# Out:
# diabetesMed
# Yes    78363
# No     23403
# Name: count, dtype: int64

# %%
diabetes_med_readmission = df.groupby("diabetesMed")["readmitted_30"].mean() * 100

print(diabetes_med_readmission)
# Out:
# diabetesMed
# No      9.597060
# Yes    11.626661
# Name: readmitted_30, dtype: float64

# %%
diabetes_med_readmission.plot(kind="bar")

plt.title("30-Day Readmission Rate by Diabetes Medication")
plt.xlabel("Diabetes Medication")
plt.ylabel("Readmission Rate (%)")
plt.xticks(rotation=0)
plt.show()

# %%
print(df["insulin"].value_counts())
# Out:
# insulin
# No        47383
# Steady    30849
# Down      12218
# Up        11316
# Name: count, dtype: int64

# %%
insulin_readmission = df.groupby("insulin")["readmitted_30"].mean() * 100

print(insulin_readmission)
# Out:
# insulin
# Down      13.897528
# No        10.037355
# Steady    11.128400
# Up        12.990456
# Name: readmitted_30, dtype: float64

# %%
print(df["insulin"].value_counts())
# Out:
# insulin
# No        47383
# Steady    30849
# Down      12218
# Up        11316
# Name: count, dtype: int64

# %%
insulin_readmission.plot(kind="bar")

plt.title("30-Day Readmission Rate by Insulin Status")
plt.xlabel("Insulin Status")
plt.ylabel("Readmission Rate (%)")
plt.xticks(rotation=0)
plt.show()

# %%
print(df["change"].value_counts())
# Out:
# change
# No    54755
# Ch    47011
# Name: count, dtype: int64

# %%
change_readmission = df.groupby("change")["readmitted_30"].mean() * 100

print(change_readmission)
# Out:
# change
# Ch    11.822765
# No    10.590814
# Name: readmitted_30, dtype: float64

# %%
print(df["admission_type_id"].value_counts().sort_index())
# Out:
# admission_type_id
# 1    53990
# 2    18480
# 3    18869
# 4       10
# 5     4785
# 6     5291
# 7       21
# 8      320
# Name: count, dtype: int64

# %%
print(df["admission_type_id"].value_counts().sort_index())
# Out:
# admission_type_id
# 1    53990
# 2    18480
# 3    18869
# 4       10
# 5     4785
# 6     5291
# 7       21
# 8      320
# Name: count, dtype: int64

# %%
admission_readmission = df.groupby("admission_type_id")["readmitted_30"].mean() * 100

print(admission_readmission)
# Out:
# admission_type_id
# 1    11.522504
# 2    11.179654
# 3    10.392708
# 4    10.000000
# 5    10.344828
# 6    11.075411
# 7     0.000000
# 8     8.437500
# Name: readmitted_30, dtype: float64

# %%
admission_readmission.plot(kind="bar")

plt.title("30-Day Readmission Rate by Admission Type")
plt.xlabel("Admission Type ID")
plt.ylabel("Readmission Rate (%)")
plt.xticks(rotation=0)
plt.show()

# %%
print(df["time_in_hospital"].value_counts().sort_index())
# Out:
# time_in_hospital
# 1     14208
# 2     17224
# 3     17756
# 4     13924
# 5      9966
# 6      7539
# 7      5859
# 8      4391
# 9      3002
# 10     2342
# 11     1855
# 12     1448
# 13     1210
# 14     1042
# Name: count, dtype: int64

# %%
hospital_stay_readmission = df.groupby("time_in_hospital")["readmitted_30"].mean() * 100

print(hospital_stay_readmission)
# Out:
# time_in_hospital
# 1      8.178491
# 2      9.939619
# 3     10.666817
# 4     11.806952
# 5     12.030905
# 6     12.587876
# 7     12.834955
# 8     14.233660
# 9     13.724184
# 10    14.346712
# 11    10.512129
# 12    13.328729
# 13    12.314050
# 14    12.955854
# Name: readmitted_30, dtype: float64

# %%
hospital_stay_readmission.plot(kind="line", marker="o")

plt.title("30-Day Readmission Rate vs Time in Hospital")
plt.xlabel("Days in Hospital")
plt.ylabel("Readmission Rate (%)")
plt.grid()
plt.show()

# %%
print(df["number_inpatient"].value_counts().sort_index())
# Out:
# number_inpatient
# 0     67630
# 1     19521
# 2      7566
# 3      3411
# 4      1622
# 5       812
# 6       480
# 7       268
# 8       151
# 9       111
# 10       61
# 11       49
# 12       34
# 13       20
# 14       10
# 15        9
# 16        6
# 17        1
# 18        1
# 19        2
# 21        1
# Name: count, dtype: int64

# %%
inpatient_readmission = df.groupby("number_inpatient")["readmitted_30"].mean() * 100

print(inpatient_readmission)
# Out:
# number_inpatient
# 0       8.437084
# 1      12.924543
# 2      17.433254
# 3      20.287306
# 4      23.612824
# 5      31.403941
# 6      34.583333
# 7      35.447761
# 8      44.370861
# 9      42.342342
# 10     42.622951
# 11     67.346939
# 12     50.000000
# 13     50.000000
# 14     40.000000
# 15    100.000000
# 16     33.333333
# 17    100.000000
# 18      0.000000
# 19     50.000000
# 21    100.000000
# Name: readmitted_30, dtype: float64

# %%
inpatient_readmission.plot(kind="line", marker="o")

plt.title("30-Day Readmission Rate vs Previous Inpatient Visits")
plt.xlabel("Previous Inpatient Visits")
plt.ylabel("Readmission Rate (%)")
plt.grid()
plt.show()

# %%
outpatient_readmission = df.groupby("number_outpatient")["readmitted_30"].mean() * 100

print(outpatient_readmission)
# Out:
# number_outpatient
# 0      10.674256
# 1      13.923014
# 2      13.745131
# 3      12.291871
# 4      15.104641
# 5      11.819887
# 6      13.201320
# 7      15.483871
# 8       5.102041
# 9      15.662651
# 10      8.771930
# 11     14.285714
# 12     20.000000
# 13     19.354839
# 14     17.857143
# 15     10.000000
# 16      0.000000
# 17     12.500000
# 18      0.000000
# 19     33.333333
# 20      0.000000
# 21      0.000000
# 22     20.000000
# 23     50.000000
# 24      0.000000
# 25      0.000000
# 26      0.000000
# 27      0.000000
# 28      0.000000
# 29      0.000000
# 33      0.000000
# 34      0.000000
# 35      0.000000
# 36      0.000000
# 37      0.000000
# 38      0.000000
# 39      0.000000
# 40    100.000000
# 42      0.000000
# Name: readmitted_30, dtype: float64

# %%
    print(df["number_outpatient"].value_counts().sort_index())
# Out:
# number_outpatient
# 0     85027
# 1      8547
# 2      3594
# 3      2042
# 4      1099
# 5       533
# 6       303
# 7       155
# 8        98
# 9        83
# 10       57
# 11       42
# 12       30
# 13       31
# 14       28
# 15       20
# 16       15
# 17        8
# 18        5
# 19        3
# 20        7
# 21        7
# 22        5
# 23        2
# 24        3
# 25        2
# 26        2
# 27        3
# 28        1
# 29        2
# 33        2
# 34        1
# 35        2
# 36        2
# 37        1
# 38        1
# 39        1
# 40        1
# 42        1
# Name: count, dtype: int64

# %%
outpatient_readmission.plot(kind="line", marker="o")

plt.title("30-Day Readmission Rate vs Previous Outpatient Visits")
plt.xlabel("Previous Outpatient Visits")
plt.ylabel("Readmission Rate (%)")
plt.grid()
plt.show()

# %%
emergency_readmission = df.groupby("number_emergency")["readmitted_30"].mean() * 100

print(emergency_readmission)
# Out:
# number_emergency
# 0      10.474315
# 1      14.354566
# 2      18.266405
# 3      20.275862
# 4      30.748663
# 5      24.479167
# 6      23.404255
# 7      26.027397
# 8      32.000000
# 9      36.363636
# 10     35.294118
# 11     21.739130
# 12     20.000000
# 13     33.333333
# 14      0.000000
# 15     33.333333
# 16     40.000000
# 18     20.000000
# 19     50.000000
# 20     50.000000
# 21     50.000000
# 22     50.000000
# 24      0.000000
# 25      0.000000
# 28    100.000000
# 29      0.000000
# 37      0.000000
# 42      0.000000
# 46      0.000000
# 54      0.000000
# 63      0.000000
# 64    100.000000
# 76      0.000000
# Name: readmitted_30, dtype: float64

# %%
numerical_features = [
    "num_lab_procedures",
    "num_procedures",
    "num_medications"
]

for col in numerical_features:
    rate = df.groupby(col)["readmitted_30"].mean() * 100
    print("\n", col)
    print(rate)
# Out:
#  num_lab_procedures
# num_lab_procedures
# 1        9.413965
# 2       11.444142
# 3        9.431138
# 4        6.349206
# 5        9.440559
#           ...
# 120      0.000000
# 121      0.000000
# 126      0.000000
# 129      0.000000
# 132    100.000000
# Name: readmitted_30, Length: 118, dtype: float64
#
#  num_procedures
# num_procedures
# 0    11.077767
# 1    12.207116
# 2    11.181883
# 3    10.685164
# 4    11.028708
# 5     9.421702
# 6     9.588212
# Name: readmitted_30, dtype: float64
#
#  num_medications
# num_medications
# 1       4.198473
# 2       8.297872
# 3       7.222222
# 4       8.045166
# 5       7.436787
#          ...
# 72    100.000000
# 74      0.000000
# 75      0.000000
# 79      0.000000
# 81    100.000000
# Name: readmitted_30, Length: 75, dtype: float64

# %%
discharge_readmission = df.groupby(
    "discharge_disposition_id"
)["readmitted_30"].mean() * 100

print(discharge_readmission.sort_values(ascending=False))
# Out:
# discharge_disposition_id
# 12    66.666667
# 15    44.444444
# 9     42.857143
# 28    36.690647
# 22    27.696939
# 5     20.861486
# 2     16.071429
# 3     14.662462
# 24    14.583333
# 7     14.446228
# 8     13.888889
# 4     12.760736
# 6     12.695706
# 18    12.435654
# 25     9.302326
# 1      9.300395
# 23     7.281553
# 14     6.451613
# 13     4.761905
# 10     0.000000
# 11     0.000000
# 16     0.000000
# 17     0.000000
# 20     0.000000
# 19     0.000000
# 27     0.000000
# Name: readmitted_30, dtype: float64

# %%
source_readmission = df.groupby(
    "admission_source_id"
)["readmitted_30"].mean() * 100

print(source_readmission.sort_values(ascending=False))
# Out:
# admission_source_id
# 22    16.666667
# 3     15.508021
# 20    13.664596
# 8     12.500000
# 5     11.812865
# 7     11.688176
# 1     10.586843
# 17    10.411444
# 9     10.400000
# 2     10.054348
# 4      9.695639
# 6      9.363958
# 10     0.000000
# 14     0.000000
# 13     0.000000
# 11     0.000000
# 25     0.000000
# Name: readmitted_30, dtype: float64

# %%
race_readmission = df.groupby(
    "race"
)["readmitted_30"].mean() * 100

print(race_readmission.sort_values(ascending=False))
# Out:
# race
# Caucasian          11.290556
# AfricanAmerican    11.218116
# Hispanic           10.407462
# Asian              10.140406
# Other               9.628154
# Name: readmitted_30, dtype: float64

# %%
numeric_cols = [
    "time_in_hospital",
    "num_lab_procedures",
    "num_procedures",
    "num_medications",
    "number_outpatient",
    "number_emergency",
    "number_inpatient",
    "number_diagnoses",
    "readmitted_30"
]

correlation = df[numeric_cols].corr()

print(correlation["readmitted_30"].sort_values(ascending=False))
# Out:
# readmitted_30         1.000000
# number_inpatient      0.165147
# number_emergency      0.060747
# number_diagnoses      0.049524
# time_in_hospital      0.044199
# num_medications       0.038432
# num_lab_procedures    0.020364
# number_outpatient     0.018893
# num_procedures       -0.012227
# Name: readmitted_30, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))

sns.heatmap(
    correlation,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Matrix of Numerical Features")
plt.show()
